# %%
import struct

# Binary file containing the data
binary_file = "event000000001-measurements.dat"

start_offset = 0  
bytes_to_read = 72

# Read the binary data
with open(binary_file, "rb") as bin_file:
    bin_file.seek(start_offset)
    raw_bytes = bin_file.read(bytes_to_read)

    # Print raw bytes in hex
    print("Raw bytes:")
    print(" ".join(f"{byte:02x}" for byte in raw_bytes))

    # Test decoding at multiple positions
    print("\nTesting float decoding at different positions:")
    for i in range(len(raw_bytes) - 1):
        try:
            value = struct.unpack("Q", raw_bytes[i:i+8])[0] # unsigned long long
            print(f"Offset {start_offset + i}: {value}")
        except struct.error as e:
            print(f"Offset {start_offset + i}: Failed to decode ({e})")
# Out:
# Raw bytes:
# 01 00 00 00 00 00 00 00 00 00 00 bf 00 00 80 be ab aa aa 3d ab aa aa 3c 7f 23 00 48 04 00 31 00 00 00 00 00 00 00 00 00 ff ff ff ff ff ff ff ff 02 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 01 00 00 00 00 00 00 00
#
# Testing float decoding at different positions:
# Offset 0: 1
# Offset 1: 0
# Offset 2: 0
# Offset 3: 0
# Offset 4: 13763000461244235776
# Offset 5: 53761720551735296
# Offset 6: 210006720905216
# Offset 7: 9223372857193529344
# Offset 8: 13726971667429720064
# Offset 9: 12375469563561574400
# Offset 10: 12298132664430411520
# Offset 11: 12297830567168180415
# Offset 12: 4443551636966604800
# Offset 13: 12339206204067577856
# Offset 14: 12297991010682388096
# Offset 15: 12297830013833227198
# Offset 16: 4371494040767212203
# Offset 17: 9168390591413594794
# Offset 18: 2557829817075187114
# Offset 19: 9991522722949949
# Offset 20: 5188185800116447915
# Offset 21: 308496726933416618
# Offset 22: 1205065339583658
# Offset 23: 3530826815144951612
# Offset 24: 13792292246659967
# Offset 25: 53876141588515
# Offset 26: 210453678080
# Offset 27: 822084680
# Offset 28: 3211268
# Offset 29: 12544
# Offset 30: 49
# Offset 31: 0
# Offset 32: 0
# Offset 33: 18374686479671623680
# Offset 34: 18446462598732840960
# Offset 35: 18446742974197923840
# Offset 36: 18446744069414584320
# Offset 37: 18446744073692774400
# Offset 38: 18446744073709486080
# Offset 39: 18446744073709551360
# Offset 40: 18446744073709551615
# Offset 41: 216172782113783807
# Offset 42: 844424930131967
# Offset 43: 3298534883327
# Offset 44: 12884901887
# Offset 45: 50331647
# Offset 46: 196607
# Offset 47: 767
# Offset 48: 2
# Offset 49: 0
# Offset 50: 0
# Offset 51: 0
# Offset 52: 0
# Offset 53: 0
# Offset 54: 0
# Offset 55: 0
# Offset 56: 0
# Offset 57: 72057594037927936
# Offset 58: 281474976710656
# Offset 59: 1099511627776
# Offset 60: 4294967296
# Offset 61: 16777216
# Offset 62: 65536
# Offset 63: 256
# Offset 64: 1
# Offset 65: Failed to decode (unpack requires a buffer of 8 bytes)
# Offset 66: Failed to decode (unpack requires a buffer of 8 bytes)
# Offset 67: Failed to decode (unpack requires a buffer of 8 bytes)
# Offset 68: Failed to decode (unpack requires a buffer of 8 bytes)
# Offset 69: Failed to decode (unpack requires a buffer of 8 bytes)
# Offset 70: Failed to decode (unpack requires a buffer of 8 bytes)
